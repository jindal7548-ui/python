# %% [markdown]
# *   List item
#
# *   List item
#
# *   List item
#
# *   List item
#
# *   List item
#
# *   List item
# *   List item
#
#
# *   List item
#
#
# *   List item
#
#
# *   List item
#
#
# *   List item
#
#
# *   List item

# %% [markdown]
# # Python

# %% [markdown]
# 1. What is python and why is it popular ?
#    - f
